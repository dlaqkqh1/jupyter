# %%
from selenium import webdriver as wb
from selenium.webdriver.common.keys import Keys
from bs4 import BeautifulSoup as bs
import time

# %%
url ="https://www.hsd.co.kr/menu/menu_list"
driver = wb.Chrome()
driver.get(url)
driver.page_source

# [더보기] 버튼을 클릭해서 전체페이지 내용이 출력되도록 함.
for i in range(3):
    driver.find_element_by_css_selector('a.c_05').click()
    time.sleep(2)

# %%
soup = bs(driver.page_source,'html.parser')
menu = soup.select('h4.h')
price = soup.select('div.item-price > strong')

# %%
for i in range(len(menu)):
    print('메뉴: ' + menu[i].text)
    print('가격: ' + price[i].text)
    print('-'*40)
# Out:
# 메뉴: 매화 (치킨, 연어구이)
# 가격: 10,000
# ----------------------------------------
# 메뉴: 매화 (순살 고등어데리야끼)
# 가격: 10,000
# ----------------------------------------
# 메뉴: 진달래
# 가격: 7,000
# ----------------------------------------
# 메뉴: 개나리 (순살 고등어데리야끼)
# 가격: 8,000
# ----------------------------------------
# 메뉴: 개나리 (순살 고등어조림)
# 가격: 8,000
# ----------------------------------------
# 메뉴: 큐브스테이크 필라프
# 가격: 6,300
# ----------------------------------------
# 메뉴: 나시고랭
# 가격: 4,500
# ----------------------------------------
# 메뉴: 순살 고등어조림
# 가격: 6,000
# ----------------------------------------
# 메뉴: 데미그라스 함박스테이크
# 가격: 6,000
# ----------------------------------------
# 메뉴: 시그니처 도시락
# 가격: 13,000
# ----------------------------------------
# 메뉴: 새치 고기고기
# 가격: 6,000
# ----------------------------------------
# 메뉴: 돈치 고기고기
# 가격: 5,200
# ----------------------------------------
# 메뉴: 고기고기
# 가격: 3,900
# ----------------------------------------
# 메뉴: 동백
# 가격: 5,000
# ----------------------------------------
# 메뉴: 치킨제육
# 가격: 4,400
# ----------------------------------------
# 메뉴: 국화
# 가격: 4,000
# ----------------------------------------
# 메뉴: 돈까스도련님
# 가격: 3,900
# ----------------------------------------
# 메뉴: 제육볶음
# 가격: 3,800
# ----------------------------------------
# 메뉴: 도련님
# 가격: 3,700
# ----------------------------------------
# 메뉴: 왕치킨마요
# 가격: 4,200
# ----------------------------------------
# 메뉴: 빅치킨마요
# 가격: 3,500
# ----------------------------------------
# 메뉴: 돈치마요
# 가격: 3,500
# ----------------------------------------
# 메뉴: 참치 샐러드마요
# 가격: 3,400
# ----------------------------------------
# 메뉴: 치킨 샐러드마요
# 가격: 3,400
# ----------------------------------------
# 메뉴: 치킨마요
# 가격: 2,900
# ----------------------------------------
# 메뉴: 참치마요
# 가격: 2,900
# ----------------------------------------
# 메뉴: 돈까스 카레
# 가격: 3,900
# ----------------------------------------
# 메뉴: 카레도시락
# 가격: 2,800
# ----------------------------------------
# 메뉴: 소불고기 철판볶음밥(A)
# 가격: 4,500
# ----------------------------------------
# 메뉴: 한솥 철판볶음밥(A)
# 가격: 3,700
# ----------------------------------------
# 메뉴: 소고기 육개장
# 가격: 4,500
# ----------------------------------------
# 메뉴: 묵은지 김치찌개
# 가격: 4,300
# ----------------------------------------
# 메뉴: 왕카레돈까스덮밥
# 가격: 5,500
# ----------------------------------------
# 메뉴: 새우돈까스 덮밥
# 가격: 3,900
# ----------------------------------------
# 메뉴: 돈까스 덮밥
# 가격: 3,600
# ----------------------------------------
# 메뉴: 치즈불닭비빔밥
# 가격: 5,700
# ----------------------------------------
# 메뉴: 불닭비빔밥
# 가격: 4,500
# ----------------------------------------
# 메뉴: 소불고기 감초고추장 비빔밥
# 가격: 4,800
# ----------------------------------------
# 메뉴: 시골제육 두부강된장 비빔밥
# 가격: 4,800
# ----------------------------------------
# 메뉴: 참치야채 감초고추장
# 가격: 3,200
# ----------------------------------------
# 메뉴: 폴리도시락
# 가격: 3,800
# ----------------------------------------
# 메뉴: 반찬 큐브스테이크
# 가격: 4,300
# ----------------------------------------
# 메뉴: 반찬 묵은지김치찌개
# 가격: 3,900
# ----------------------------------------
# 메뉴: 반찬 소고기육개장
# 가격: 4,100
# ----------------------------------------
# 메뉴: 반찬 카레
# 가격: 2,400
# ----------------------------------------
# 메뉴: 반찬 데미함박스테이크
# 가격: 5,000
# ----------------------------------------
# 메뉴: 반찬 소불고기
# 가격: 3,900
# ----------------------------------------
# 메뉴: 반찬 순살 고등어데리야끼
# 가격: 3,400
# ----------------------------------------
# 메뉴: 반찬 치킨
# 가격: 3,200
# ----------------------------------------
# 메뉴: 반찬 고기고기
# 가격: 3,200
# ----------------------------------------
# 메뉴: 반찬 돈까스 도련님
# 가격: 3,200
# ----------------------------------------
# 메뉴: 반찬 제육볶음
# 가격: 3,100
# ----------------------------------------
# 메뉴: 반찬 돈까스
# 가격: 2,500
# ----------------------------------------
# 메뉴: 반찬 순살 고등어조림
# 가격: 5,000
# ----------------------------------------
# 메뉴: 감자 고로케
# 가격: 2,000
# ----------------------------------------
# 메뉴: 교자만두
# 가격: 2,800
# ----------------------------------------
# 메뉴: 케이준후라이
# 가격: 1,500
# ----------------------------------------
# 메뉴: 치킨 샐러드(유자드레싱)
# 가격: 3,600
# ----------------------------------------
# 메뉴: 치킨 샐러드(사과드레싱)
# 가격: 3,600
# ----------------------------------------
# 메뉴: 그린 샐러드 (유자드레싱)
# 가격: 2,900
# ----------------------------------------
# 메뉴: 그린 샐러드 (사과드레싱)
# 가격: 2,900
# ----------------------------------------
# 메뉴: 미니 샐러드 (유자드레싱)
# 가격: 1,500
# ----------------------------------------
# 메뉴: 미니 샐러드 (사과드레싱)
# 가격: 1,500
# ----------------------------------------
# 메뉴: 와인페어링
# 가격: 7,500
# ----------------------------------------
# 메뉴: 소주페어링
# 가격: 6,500
# ----------------------------------------
# 메뉴: 맥주페어링
# 가격: 6,500
# ----------------------------------------
# 메뉴: 토마토 야채수프
# 가격: 3,500
# ----------------------------------------
# 메뉴: 단호박 수프
# 가격: 3,000
# ----------------------------------------
# 메뉴: 닭강정(중)
# 가격: 7,500
# ----------------------------------------
# 메뉴: 닭강정(소)
# 가격: 2,800
# ----------------------------------------
# 메뉴: 치킨 BOX(대)
# 가격: 10,000
# ----------------------------------------
# 메뉴: 치킨BOX(중)_양식소스
# 가격: 5,000
# ----------------------------------------
# 메뉴: 치킨BOX(중)_칠리소스
# 가격: 5,000
# ----------------------------------------
# 메뉴: 필라프
# 가격: 2,000
# ----------------------------------------
# 메뉴: 영양밥
# 가격: 2,200
# ----------------------------------------
# 메뉴: 현미밥
# 가격: 1,700
# ----------------------------------------
# 메뉴: 한솥밥
# 가격: 1,000
# ----------------------------------------
# 메뉴: 볶음김치
# 가격: 400
# ----------------------------------------
# 메뉴: 김치
# 가격: 300
# ----------------------------------------
# 메뉴: 무말랭이
# 가격: 300
# ----------------------------------------

# %%
import pandas as pd

# %%
menus =[]
prices = []
for i in range(len(menu)):
    menus.append(menu[i].text.strip())
    prices.append(price[i].text)

# %%
data = {'menu': menus, 'price': prices}
df = pd.DataFrame(data)
df
# Out:
#                 menu   price
# 0      매화 (치킨, 연어구이)  10,000
# 1    매화 (순살 고등어데리야끼)  10,000
# 2                진달래   7,000
# 3   개나리 (순살 고등어데리야끼)   8,000
# 4     개나리 (순살 고등어조림)   8,000
# 5         큐브스테이크 필라프   6,300
# 6               나시고랭   4,500
# 7           순살 고등어조림   6,000
# 8       데미그라스 함박스테이크   6,000
# 9           시그니처 도시락  13,000
# 10           새치 고기고기   6,000
# 11           돈치 고기고기   5,200
# 12              고기고기   3,900
# 13                동백   5,000
# 14              치킨제육   4,400
# 15                국화   4,000
# 16            돈까스도련님   3,900
# 17              제육볶음   3,800
# 18               도련님   3,700
# 19             왕치킨마요   4,200
# 20             빅치킨마요   3,500
# 21              돈치마요   3,500
# 22          참치 샐러드마요   3,400
# 23          치킨 샐러드마요   3,400
# 24              치킨마요   2,900
# 25              참치마요   2,900
# 26            돈까스 카레   3,900
# 27             카레도시락   2,800
# 28     소불고기 철판볶음밥(A)   4,500
# 29       한솥 철판볶음밥(A)   3,700
# ..               ...     ...
# 50        반찬 돈까스 도련님   3,200
# 51           반찬 제육볶음   3,100
# 52            반찬 돈까스   2,500
# 53       반찬 순살 고등어조림   5,000
# 54            감자 고로케   2,000
# 55              교자만두   2,800
# 56            케이준후라이   1,500
# 57     치킨 샐러드(유자드레싱)   3,600
# 58     치킨 샐러드(사과드레싱)   3,600
# 59    그린 샐러드 (유자드레싱)   2,900
# 60    그린 샐러드 (사과드레싱)   2,900
# 61    미니 샐러드 (유자드레싱)   1,500
# 62    미니 샐러드 (사과드레싱)   1,500
# 63             와인페어링   7,500
# 64             소주페어링   6,500
# 65             맥주페어링   6,500
# 66          토마토 야채수프   3,500
# 67            단호박 수프   3,000
# 68            닭강정(중)   7,500
# 69            닭강정(소)   2,800
# 70         치킨 BOX(대)  10,000
# 71     치킨BOX(중)_양식소스   5,000
# 72     치킨BOX(중)_칠리소스   5,000
# 73               필라프   2,000
# 74               영양밥   2,200
# 75               현미밥   1,700
# 76               한솥밥   1,000
# 77              볶음김치     400
# 78                김치     300
# 79              무말랭이     300
#
# [80 rows x 2 columns]
