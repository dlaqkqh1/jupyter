# %% [markdown]
# ## 1. 판다스, 넘파이 모듈 임포트하기

# %%
import pandas as pd

# %% [markdown]
# ### 2. Datasets/direct_marketing.csv 파일 불러오기

# %%
data = pd.read_csv("Datasets/direct_marketing.csv")

# %% [markdown]
# ## 3. 상위 5개의 데이터만 출력하기

# %%
data.head(5)
# Out:
#    recency history_segment  history  mens  womens   zip_code  newbie channel  \
# 0       10  2) $100 - $200   142.44     1       0  Surburban       0   Phone
# 1        6  3) $200 - $350   329.08     1       1      Rural       1     Web
# 2        7  2) $100 - $200   180.65     0       1  Surburban       1     Web
# 3        9  5) $500 - $750   675.83     1       0      Rural       1     Web
# 4        2    1) $0 - $100    45.34     1       0      Urban       0     Web
#
#          segment  visit  conversion  spend  DM_category
# 0  Womens E-Mail      0           0    0.0            4
# 1      No E-Mail      0           0    0.0           11
# 2  Womens E-Mail      0           0    0.0            1
# 3    Mens E-Mail      0           0    0.0            2
# 4  Womens E-Mail      0           0    0.0            4

# %% [markdown]
# ## 4. 'recency'  열 데이터 출력하기

# %%
data['recency']
# Out:
# 0        10
# 1         6
# 2         7
# 3         9
# 4         2
# 5         6
# 6         9
# 7         9
# 8         9
# 9        10
# 10        7
# 11        1
# 12        5
# 13        2
# 14        4
# 15        3
# 16        5
# 17        9
# 18       11
# 19        5
# 20        9
# 21       11
# 22        2
# 23        2
# 24        4
# 25        6
# 26       12
# 27        6
# 28        7
# 29        2
#          ..
# 63970     4
# 63971     5
# 63972     3
# 63973     8
# 63974     8
# 63975    10
# 63976     1
# 63977     8
# 63978    10
# 63979    10
# 63980     3
# 63981     4
# 63982     5
# 63983     2
# 63984     2
# 63985     9
# 63986     9
# 63987     1
# 63988     6
# 63989    10
# 63990     6
# 63991     1
# 63992     1
# 63993     4
# 63994     7
# 63995    10
# 63996     5
# 63997     6
# 63998     1
# 63999     1
# Name: recency, Length: 64000, dtype: int64

# %% [markdown]
# ## 5. loc 속성을 이용하여 'recency' 열 데이터 출력하기

# %%
data.loc[:,'recency']

# %% [markdown]
# ## 6. iloc 속성을 이용하여 'recency' 열 데이터 출력하기

# %%
data.iloc[:, 0]
# Out:
# 0        10
# 1         6
# 2         7
# 3         9
# 4         2
# 5         6
# 6         9
# 7         9
# 8         9
# 9        10
# 10        7
# 11        1
# 12        5
# 13        2
# 14        4
# 15        3
# 16        5
# 17        9
# 18       11
# 19        5
# 20        9
# 21       11
# 22        2
# 23        2
# 24        4
# 25        6
# 26       12
# 27        6
# 28        7
# 29        2
#          ..
# 63970     4
# 63971     5
# 63972     3
# 63973     8
# 63974     8
# 63975    10
# 63976     1
# 63977     8
# 63978    10
# 63979    10
# 63980     3
# 63981     4
# 63982     5
# 63983     2
# 63984     2
# 63985     9
# 63986     9
# 63987     1
# 63988     6
# 63989    10
# 63990     6
# 63991     1
# 63992     1
# 63993     4
# 63994     7
# 63995    10
# 63996     5
# 63997     6
# 63998     1
# 63999     1
# Name: recency, Length: 64000, dtype: int64

# %% [markdown]
# ## 7. 'recency' 값이 7보다 작은 행만 출력하기

# %%
data['recency'][data['recency'] < 7]
# Out:
# 1        6
# 4        2
# 5        6
# 11       1
# 12       5
# 13       2
# 14       4
# 15       3
# 16       5
# 19       5
# 22       2
# 23       2
# 24       4
# 25       6
# 27       6
# 29       2
# 30       2
# 32       6
# 34       3
# 35       4
# 36       1
# 37       4
# 41       3
# 43       2
# 44       1
# 46       2
# 47       1
# 48       3
# 50       3
# 55       6
#         ..
# 63949    5
# 63950    1
# 63953    5
# 63954    2
# 63955    1
# 63960    1
# 63961    4
# 63964    2
# 63966    4
# 63967    5
# 63969    3
# 63970    4
# 63971    5
# 63972    3
# 63976    1
# 63980    3
# 63981    4
# 63982    5
# 63983    2
# 63984    2
# 63987    1
# 63988    6
# 63990    6
# 63991    1
# 63992    1
# 63993    4
# 63996    5
# 63997    6
# 63998    1
# 63999    1
# Name: recency, Length: 36585, dtype: int64

# %% [markdown]
# ## 8. 'recency'값이 7보다 작고 'newbie' 값이 0인 행만 출력하기

# %%
data[:][data['recency'] < 7][data['newbie'] == 0]
# Out:
# D:\Program Files\anaconda\lib\site-packages\ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
#        recency history_segment  history  mens  womens   zip_code  newbie  \
# 4            2    1) $0 - $100    45.34     1       0      Urban       0
# 5            6  2) $100 - $200   134.83     0       1  Surburban       0
# 13           2  2) $100 - $200   101.64     0       1      Urban       0
# 16           5    1) $0 - $100    29.99     1       0  Surburban       0
# 22           2  2) $100 - $200   118.40     1       0  Surburban       0
# 24           4    1) $0 - $100    78.24     1       0  Surburban       0
# 27           6  2) $100 - $200   162.98     0       1  Surburban       0
# 29           2  3) $200 - $350   203.35     1       0      Rural       0
# 30           2  3) $200 - $350   237.53     0       1  Surburban       0
# ...
