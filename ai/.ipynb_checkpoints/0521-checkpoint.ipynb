# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

img = cv2.imread('temp.jpg')
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
plt.show()

# %%
imgray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
plt.imshow(imgray, cmap = "gray")
plt.show()

# %%
templ = cv2.imread("feat.jpg", cv2.IMREAD_GRAYSCALE)
plt.imshow(templ, cmap="gray")
plt.show()

# %%
print(templ.shape)
h, w = templ.shape[:2]
# Out:
# (231, 238)

# %%
res = cv2.matchTemplate(imgray, templ, cv2.TM_CCOEFF_NORMED)
loc = np.where(res>=0.8)
print(loc)
# Out:
# (array([521, 522, 522, 522, 522, 522, 522, 522, 522, 522, 523, 523, 523,
#        523, 523, 523, 523, 523, 523, 523, 524, 524, 524, 524, 524, 524,
#        524, 524, 524, 524, 524, 525, 525, 525, 525, 525, 525, 525, 525,
#        525, 525, 525, 526, 526, 526, 526, 526, 526, 526, 526, 526, 526,
#        526, 527, 527, 527, 527, 527, 527, 527, 527, 527, 527, 527, 528,
#        528, 528, 528, 528, 528, 528, 528, 528, 528, 528, 529, 529, 529,
#        529, 529, 529, 529, 529, 529, 529, 529, 530, 530, 530, 530, 530,
#        530, 530, 530, 530, 530, 530, 531, 531, 531, 531, 531, 531, 531,
#        531, 531, 531, 531, 532, 532, 532, 532, 532, 532, 532, 532, 532,
#        532, 532, 533, 533, 533, 533, 533, 533, 533, 533, 533, 534, 534,
#        534, 534, 534, 534, 534, 534], dtype=int64), array([220, 217, 218, 219, 220, 221, 222, 223, 224, 225, 216, 217, 218,
#        219, 220, 221, 222, 223, 224, 225, 216, 217, 218, 219, 220, 221,
#        222, 223, 224, 225, 226, 216, 217, 218, 219, 220, 221, 222, 223,
#        224, 225, 226, 216, 217, 218, 219, 220, 221, 222, 223, 224, 225,
#        226, 216, 217, 218, 219, 220, 221, 222, 223, 224, 225, 226, 216,
#        217, 218, 219, 220, 221, 222, 223, 224, 225, 226, 216, 217, 218,
#        219, 220, 221, 222, 223, 224, 225, 226, 216, 217, 218, 219, 220,
#        221, 222, 223, 224, 225, 226, 216, 217, 218, 219, 220, 221, 222,
#        223, 224, 225, 226, 216, 217, 218, 219, 220, 221, 222, 223, 224,
#        225, 226, 217, 218, 219, 220, 221, 222, 223, 224, 225, 217, 218,
#        219, 220, 221, 222, 223, 224], dtype=int64))

# %%
for pt in zip(*loc[::-1]):
    cv2.rectangle(img, pt, (pt[0] + w, pt[1] + h), (0, 0, 255), 1)
    
plt.imshow(res, cmap="gray")
plt.title("Matching Result")
plt.show()

plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
plt.title('Detected Point')
plt.show()

cv2.imshow('Detected Point', img)
cv2.waitKey(0)
cv2.destroyAllWindows()
